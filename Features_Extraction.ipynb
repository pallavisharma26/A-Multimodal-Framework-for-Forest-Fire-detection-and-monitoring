# %%
import numpy as np
import pandas as pd
from skimage import filters
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
from skimage import feature
# %matplotlib inline
from skimage.filters import prewitt_h,prewitt_v

# %%
image1 = imread('./final code/fire.133.png')
imshow(image1);

# %%
image2 = imread('./final code/fire.133.png', as_gray=True)
imshow(image2);

# %%
#Shape of images
print(image1.shape)
print(image2.shape)
# Out:
# (330, 660, 3)
# (330, 660)

# %%
print(image1.size)
print(image2.size)
# Out:
# 653400
# 217800

# %%
pixel_feat2 = np.reshape(image1, (720*1280*3))
pixel_feat2

# %%
pre_hor = prewitt_h(image2)
pre_ver = prewitt_v(image2)





imshow(pre_hor, cmap='gray');

# %%
imshow(pre_ver, cmap='gray');

# %%
# Sobel Kernel
ed_sobel = filters.sobel(image2)
imshow(ed_sobel, cmap='gray');

# %%
# canny algorithm
edges = feature.canny(image2,sigma=3)
imshow(edges, cmap='gray');
